# %% [markdown]
# # Question_Paper_Analysis

# %%
import pandas as pd
df=pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %% [markdown]
#  Imports pandas and reads data from class_marks.csv into a DataFrame.

# %%
df[df.Total==40]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 33     40    NaN    NaN    6.0    4.0    5.0    5.0    3.0    7.0    NaN
# 51     40    0.0    NaN    6.0    4.0    NaN    NaN    3.0    7.0   10.0
# 53     40    4.0    6.0    6.0    4.0    5.0    5.0    NaN    NaN   10.0
# 65     40    4.0    6.0    6.0    4.0    5.0    5.0    NaN    NaN   10.0
# 73     40    4.0    6.0    NaN    NaN    5.0    5.0    3.0    NaN   10.0
#
#     Q6aM4  Q6bM6
# 33    4.0    6.0
# 51    NaN    NaN
# 53    NaN    NaN
# 65    NaN    NaN
# 73    4.0    6.0

# %% [markdown]
# Filters rows where the Total column equals 40.

# %%
df.replace(39,40).Total.value_counts()
# Out:
# Total
# 40    7
# 36    7
# 32    6
# 34    5
# 38    5
# 37    4
# 27    4
# 29    4
# 25    4
# 20    4
# 33    4
# 24    4
# 26    3
# 30    3
# 22    3
# 35    3
# 31    3
# 28    3
# 21    2
# 17    2
# 14    1
# 9     1
# 8     1
# 19    1
# 18    1
# 3     1
# Name: count, dtype: int64

# %% [markdown]
#  Replaces values of 39 with 40 and counts occurrences of Total values.

# %%
df=df.replace(40,39)

# %% [markdown]
# Replaces values of 40 with 39 in the DataFrame

# %%
df.value_counts()
# Out:
# Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  Q6aM4  Q6bM6
# 34     4.0    4.0    5.0    3.0    2.0    2.0    2.0    1.0    9.0    2.0    2.0      1
# Name: count, dtype: int64

# %% [markdown]
# Displays the value counts for all columns in the DataFrame.

# %%
df.Total.value_counts()
# Out:
# Total
# 39    7
# 36    7
# 32    6
# 34    5
# 38    5
# 37    4
# 27    4
# 29    4
# 25    4
# 20    4
# 33    4
# 24    4
# 26    3
# 30    3
# 22    3
# 35    3
# 31    3
# 28    3
# 21    2
# 17    2
# 14    1
# 9     1
# 8     1
# 19    1
# 18    1
# 3     1
# Name: count, dtype: int64

# %% [markdown]
# Displays value counts for the Total column.

# %%
df["Q1"]=df["Q1aM4"]+df["Q1bM6"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1
# 0     4.0    6.0   9.0
# 1     NaN    NaN   7.0
# ...

# %% [markdown]
#  Creates a new column Q1 by summing Q1aM4 and Q1bM6.

# %%
df["Q2"]=df["Q2aM6"]+df["Q2bM4"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2
# 0     4.0    6.0   9.0  10.0
# 1     NaN    NaN   7.0   7.0
# ...

# %% [markdown]
# Creates a new column Q2 by summing Q2aM6 and Q2bM4

# %%
df["Q3"]=df["Q3aM5"]+df["Q3bM5"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3
# 0     4.0    6.0   9.0  10.0   3.0
# ...

# %% [markdown]
# Creates a new column Q3 by summing Q3aM5 and Q3bM5.

# %%
df["Q4"]=df["Q4aM3"]+df["Q4bM7"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4
# 0     4.0    6.0   9.0  10.0   3.0  NaN
# ...

# %% [markdown]
# Creates a new column Q4 by summing Q4aM3 and Q4bM7.

# %%
df["Q5"]=df["Q5M10"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q5
# ...

# %% [markdown]
# # Creates a new column Q5 by assigning values from Q5M10.

# %%
df["Q6"]=df["Q6aM4"]+df["Q6bM6"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# ...

# %% [markdown]
# # Creates a new column Q6 by summing Q6aM4 and Q6bM6.

# %%
df.fillna(0, inplace=True)
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    0.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    0.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    7.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    9.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    6.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# ...

# %% [markdown]
# # Fills missing values in the DataFrame with 0.

# %%
df1 = df.drop(["Q2aM6", "Q2bM4","Q3aM5","Q3bM5","Q4aM3","Q4bM7","Q5M10","Q6aM4","Q6bM6"], axis=1)
df1
# Out:
#     Total  Q1aM4  Q1bM6    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37    4.0    5.0   9.0  10.0   3.0  0.0   8.0  10.0
# 1      32    4.0    3.0   7.0   7.0   0.0  9.0   9.0   0.0
# 2      33    4.0    5.0   9.0   6.0  10.0  0.0   8.0   0.0
# 3      24    4.0    6.0  10.0   9.0   4.0  0.0   0.0   0.0
# 4      36    3.0    6.0   9.0   8.0   9.0  0.0  10.0   0.0
# ..    ...    ...    ...   ...   ...   ...  ...   ...   ...
# 81     32    3.0    6.0   9.0   7.0   8.0  0.0   0.0  10.0
# 82     27    2.0    2.0   4.0   8.0   0.0  0.0   7.0   8.0
# 83     37    4.0    6.0  10.0   8.0   0.0  0.0   9.0  10.0
# 84     28    4.0    0.0   0.0   9.0   9.0  0.0   6.0   0.0
# 85     29    4.0    6.0  10.0   0.0   0.0  8.0   7.0   5.0
#
# [86 rows x 9 columns]

# %% [markdown]
# # Drops specific columns related to individual question parts to create a simplified DataFrame.

# %%
import matplotlib.pyplot as plt

# %%
df1=df.groupby('Q1')['Total']
df1.hist(color = 'blue',figsize=[8,8],edgecolor='black',grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q1")
plt.show()

# %% [markdown]
# # Most of the students are scored above 8 marks in Q1

# %%
df1=df.groupby('Q2')['Total']
df1.hist(color = 'yellow',figsize=[8,8],edgecolor='black',grid=False,bins=7)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q2")
plt.show()

# %% [markdown]
# # Most of the students are scored above 12 marks in Q2

# %%
plt.hist(df['Q1'],color='purple',edgecolor='black',bins=9)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
# # Most of the students are scored above 8 marks in Q1 In above 8 Most of the sudents got 10 marks

# %%
plt.hist(df['Q2'],color='orange',edgecolor='black',bins=5)
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# # Q2 is the most easiest question because most of the students answerd this question they got 10 marks

# %%
plt.hist(df['Q3'],color='green',edgecolor='black',bins=3)
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# # Students feels this Question also the most easiest question because so may studensts got the 10 marks nearly more than 25 students

# %%
plt.hist(df['Q4'],color='cyan',edgecolor='black',bins=3)
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# # Here most of the students scored above 6 marks in that above 6 more no.of students got 10 marks

# %%
plt.hist(df['Q5'],color='yellow',edgecolor='black',bins=3)
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")
plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %% [markdown]
# # here most of the students got above 7 marks int that most of the students got the 10 marks

# %%
plt.hist(df['Q6'],color='brown',edgecolor='black',bins=3)
plt.xlabel("Marks scored in Q6")
plt.ylabel("No.of students")
plt.title("Histogram of Q6")
# Out:
# Text(0.5, 1.0, 'Histogram of Q6')

# %% [markdown]
# # This question also most of the students felt easy and nearly 16 members of tudents got 10 marks in Q6

# %%
df1.plot()
plt.show()

# %% [markdown]
# # This code generates a default line plot for all columns in `df1` and then displays the plot.

# %%
df.plot.scatter(x = 'Q1', y = 'Total',color='brown',s=30)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %% [markdown]
# # It is a Scatter Plotting . Here we are giving the plots for the 1Q

# %%
df.plot.scatter(x = 'Q2', y = 'Total',color='yellow',s=30)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %% [markdown]
# # This is the Scatter Plotting for the 2Q

# %%
df.plot.scatter(x = 'Q3', y = 'Total',color='purple',s=30)
plt.title("Scatter Plot for Q3")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q3')

# %% [markdown]
# # This is the Scatter Plotting for the Q3

# %%
df.plot.scatter(x = 'Q4', y = 'Total',color='cyan',s=30)
plt.title("Scatter Plot for Q4")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q4')

# %% [markdown]
# # This is the Scatter Plotting for the Q4

# %%
df.plot.scatter(x = 'Q5', y = 'Total',color='Magenta',s=30)
plt.title("Scatter Plot for Q5")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q5')

# %% [markdown]
# # Here most of the students got 7 and above 7 marks

# %%
df.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Most of the students scored between 7 and 10 in Q1

# %%
df.plot.line(x='Q2',y='Total',color='cyan')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Most of the students scored between 8 and 10 in Q2

# %%
import pandas as pd
df1 = pd.read_csv("class_marks.csv", skiprows=70)
print(df1)
df1['3'].plot(kind='pie', figsize=(8, 10))
plt.title("Piechart of marks in Q1")
# Out:
#      3  1  Unnamed: 2  1.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  1.2  \
# 0   35  4         6.0  6.0         4.0         5.0         5.0  NaN
# 1   36  4         5.0  6.0         4.0         5.0         5.0  NaN
# 2   25  2         NaN  4.0         4.0         NaN         5.0  3.0
# 3   40  4         6.0  NaN         NaN         5.0         5.0  3.0
# 4   25  1         5.0  6.0         4.0         NaN         NaN  NaN
# 5   21  4         NaN  6.0         1.0         1.0         1.0  NaN
# 6   17  2         3.0  4.0         2.0         4.0         2.0  NaN
# 7   22  4         5.0  NaN         NaN         3.0         2.0  2.0
# 8   33  2         3.0  6.0         4.0         5.0         5.0  NaN
# 9   27  2         6.0  NaN         3.0         2.0         5.0  NaN
# 10  31  4         6.0  6.0         2.0         2.0         5.0  NaN
# 11  32  3         6.0  3.0         4.0         5.0         3.0  NaN
# 12  27  2         2.0  5.0         3.0         NaN         NaN  NaN
# ...

# %% [markdown]
# #  skipping the first 70 rows prints it, and plots a pie chart of the values in column `3` with the title "Piechart of marks in Q1".

# %%
df1 = pd.read_csv("class_marks.csv", skiprows=70)
print(df1)
df1['3'].plot(kind='pie', figsize=(6, 7))
plt.title("Piechart of marks in Q2")
# Out:
#      3  1  Unnamed: 2  1.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  1.2  \
# 0   35  4         6.0  6.0         4.0         5.0         5.0  NaN
# 1   36  4         5.0  6.0         4.0         5.0         5.0  NaN
# 2   25  2         NaN  4.0         4.0         NaN         5.0  3.0
# 3   40  4         6.0  NaN         NaN         5.0         5.0  3.0
# 4   25  1         5.0  6.0         4.0         NaN         NaN  NaN
# 5   21  4         NaN  6.0         1.0         1.0         1.0  NaN
# 6   17  2         3.0  4.0         2.0         4.0         2.0  NaN
# 7   22  4         5.0  NaN         NaN         3.0         2.0  2.0
# 8   33  2         3.0  6.0         4.0         5.0         5.0  NaN
# 9   27  2         6.0  NaN         3.0         2.0         5.0  NaN
# 10  31  4         6.0  6.0         2.0         2.0         5.0  NaN
# 11  32  3         6.0  3.0         4.0         5.0         3.0  NaN
# 12  27  2         2.0  5.0         3.0         NaN         NaN  NaN
# ...

# %% [markdown]
# # skipping the first 70 rows, prints it, and plots a pie chart of the values in column `3` with the title "Piechart of marks in Q2".

# %%
import pandas as pd
df1 = pd.read_csv("class_marks.csv", skiprows=80)
print(df1)
df1['3'].plot(kind='pie', figsize=(8, 10))
plt.title("Piechart of marks in Q3")
# Out:
#    27  2    6  Unnamed: 3    3  2.1    5  Unnamed: 7  Unnamed: 8    9  \
# 0  31  4  6.0         6.0  2.0  2.0  5.0         NaN         NaN  6.0
# 1  32  3  6.0         3.0  4.0  5.0  3.0         NaN         NaN  NaN
# 2  27  2  2.0         5.0  3.0  NaN  NaN         NaN         NaN  7.0
# 3  37  4  6.0         6.0  2.0  NaN  NaN         NaN         NaN  9.0
# 4  28  4  NaN         5.0  4.0  5.0  4.0         NaN         NaN  6.0
# 5  29  4  6.0         NaN  NaN  NaN  NaN         3.0         5.0  7.0
#
#    Unnamed: 10  Unnamed: 11
# 0          NaN          NaN
# 1          4.0          6.0
# 2          3.0          5.0
# 3          4.0          6.0
# 4          NaN          NaN
# 5          1.0          4.0
# Text(0.5, 1.0, 'Piechart of marks in Q3')

# %% [markdown]
# # skipping the first 70 rows, prints it, and plots a pie chart of the values in column 3 with the title "Piechart of marks in Q3".

# %%
import pandas as pd
df1 = pd.read_csv("class_marks.csv", skiprows=50)
print(df1)
df1['3'].plot(kind='pie', figsize=(8, 10))
plt.title("Piechart of marks in Q4")
# Out:
#     39  3    6  6.1    4    5  5.1  Unnamed: 7  Unnamed: 8    10  Unnamed: 10  \
# 0   24  4  5.0  NaN  NaN  5.0  5.0         NaN         NaN   5.0          4.0
# 1   40  0  NaN  6.0  4.0  NaN  NaN         3.0         7.0  10.0          NaN
# 2   29  4  5.0  4.0  3.0  NaN  NaN         3.0         6.0   4.0          NaN
# 3   40  4  6.0  6.0  4.0  5.0  5.0         NaN         NaN  10.0          NaN
# 4   21  2  6.0  NaN  NaN  5.0  5.0         3.0         NaN   NaN          4.0
# 5   38  3  5.0  6.0  4.0  NaN  NaN         NaN         NaN  10.0          4.0
# 6   35  2  6.0  NaN  NaN  NaN  NaN         3.0         7.0   7.0          4.0
# 7   17  3  NaN  NaN  4.0  NaN  NaN         3.0         7.0   NaN          4.0
# 8   34  4  5.0  6.0  3.0  NaN  NaN         3.0         NaN   6.0          NaN
# 9   38  2  6.0  6.0  4.0  5.0  5.0         NaN         NaN  10.0          4.0
# 10  20  2  5.0  3.0  2.0  NaN  NaN         NaN         NaN   8.0          NaN
# ...

# %% [markdown]
# # skipping the first 70 rows, prints it, and plots a pie chart of the values in column 3 with the title "Piechart of marks in Q4".

# %%
df.boxplot(by='Q1', column =['Total'], grid = False,color='Orange')
plt.title("Boxplot of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This code creates an orange box plot to display the distribution of `Total` marks grouped by `Q1`, with a title and labeled y-axis, and then displays the plot.

# %%
df.boxplot(by='Q2', column =['Total'], grid = False,color='red')
plt.title("Boxplot of Q2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This code creates an orange box plot to display the distribution of `Total` marks grouped by `Q2`, with a title and labeled y-axis, and then displays the plot.

# %%
df.boxplot(by='Q3', column =['Total'], grid = False,color='green')
plt.title("Boxplot of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This code creates an orange box plot to display the distribution of `Total` marks grouped by `Q3`, with a title and labeled y-axis, and then displays the plot.

# %%
df.boxplot(by='Q4', column =['Total'], grid = False,color='cyan')
plt.title("Boxplot of Q4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This code creates an orange box plot to display the distribution of `Total` marks grouped by `Q4`, with a title and labeled y-axis, and then displays the plot.

# %%
df.boxplot(by='Q5', column =['Total'], grid = False,color='yellow')
plt.title("Boxplot of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This code creates an orange box plot to display the distribution of `Total` marks grouped by `Q5`, with a title and labeled y-axis, and then displays the plot.

# %%
df.boxplot(by='Q6', column =['Total'], grid = False,color='cyan')
plt.title("Boxplot of Q6")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This code creates an orange box plot to display the distribution of `Total` marks grouped by `Q6`, with a title and labeled y-axis, and then displays the plot.
